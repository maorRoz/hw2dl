# %% [markdown]
# # Category Embedding

# %% [markdown]
# ### We joined the Elo multi-target competition on Kaggle.
#
# A few words about the competition:
# Elo, one of the largest payment brands in Brazil, has built partnerships with merchants in order to offer promotions or discounts to cardholders. But do these promotions work for either the consumer or the merchant? Do customers enjoy their experience? Do merchants see repeat business? Personalization is key.
#
# Elo has built machine learning models to understand the most important aspects and preferences in their customers’ lifecycle, from food to shopping. But so far none of them is specifically tailored for an individual or profile.
#
# In this competition, we are expected to develop algorithms to identify and serve the most relevant opportunities to individuals, by uncovering signal in customer loyalty. Your input will improve customers’ lives and help Elo reduce unwanted campaigns, to create the right experience for customers.

# %%
from keras.models import Model
from keras.layers import *
from keras.callbacks import *
from keras.regularizers import l2
from keras.optimizers import *
from keras.utils import to_categorical
import pandas as pd
import numpy as np
import datetime
import seaborn as sns 
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
 
import xgboost as xgb
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data Analysis:

# %% [markdown]
# Lets load the given data in order to understand the different attrivutes and the data shape.

# %%
train = pd.read_csv("../input/train.csv")
print("shape of train : ",train.shape)
# Out:
# shape of train :  (201917, 6)

# %%
train.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target
# 0 -0.820283
# 1  0.392913
# 2  0.688056
# 3  0.142495
# 4 -0.159749

# %%
test = pd.read_csv("../input/test.csv")
print("shape of test : ",test.shape)
# Out:
# shape of test :  (123623, 5)

# %%
test.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3
# 0            2017-04  C_ID_0ab67a22ab          3          3          1
# 1            2017-01  C_ID_130fd0cbdd          2          3          0
# 2            2017-08  C_ID_b709037bc5          5          1          1
# 3            2017-12  C_ID_d27d835a9f          2          1          0
# 4            2015-12  C_ID_2b5e3df5c2          5          1          1

# %%
merchants = pd.read_csv("../input/merchants.csv")
print("shape of merchants : ",merchants.shape)
merchants.head()
# Out:
# shape of merchants :  (334696, 22)
#        merchant_id  merchant_group_id  merchant_category_id  subsector_id  \
# 0  M_ID_838061e48c               8353                   792             9
# 1  M_ID_9339d880ad               3184                   840            20
# 2  M_ID_e726bbae1e                447                   690             1
# 3  M_ID_a70e9c5f81               5026                   792             9
# 4  M_ID_64456c37ce               2228                   222            21
#
#    numerical_1  numerical_2 category_1 most_recent_sales_range  \
# 0    -0.057471    -0.057471          N                       E
# 1    -0.057471    -0.057471          N                       E
# 2    -0.057471    -0.057471          N                       E
# 3    -0.057471    -0.057471          Y                       E
# 4    -0.057471    -0.057471          Y                       E
#
#   most_recent_purchases_range  avg_sales_lag3     ...      avg_sales_lag6  \
# 0                           E           -0.40     ...               -2.25
# 1                           E           -0.72     ...               -0.74
# 2                           E          -82.13     ...              -82.13
# 3                           E             NaN     ...                 NaN
# 4                           E             NaN     ...                 NaN
#
#    avg_purchases_lag6  active_months_lag6  avg_sales_lag12  \
# 0           18.666667                   6            -2.32
# 1            1.291667                   6            -0.57
# 2          260.000000                   2           -82.13
# 3            4.666667                   6              NaN
# 4            0.361111                   6              NaN
#
#    avg_purchases_lag12  active_months_lag12  category_4  city_id state_id  \
# 0            13.916667                   12           N      242        9
# 1             1.687500                   12           N       22       16
# 2           260.000000                    2           N       -1        5
# 3             3.833333                   12           Y       -1       -1
# 4             0.347222                   12           Y       -1       -1
#
#    category_2
# 0         1.0
# 1         1.0
# 2         5.0
# 3         NaN
# 4         NaN
#
# [5 rows x 22 columns]

# %%
historical_transactions = pd.read_csv("../input/historical_transactions.csv")
historical_transactions.drop(['authorized_flag','category_1','installments','category_3','category_2','state_id','subsector_id','city_id'],axis = 1, inplace = True)
print("shape of merchants : ",historical_transactions.shape)
historical_transactions.head()
# Out:
# shape of merchants :  (29112361, 6)
#            card_id  merchant_category_id      merchant_id  month_lag  \
# 0  C_ID_4e6213e9bc                    80  M_ID_e020e9b302         -8
# 1  C_ID_4e6213e9bc                   367  M_ID_86ec983688         -7
# 2  C_ID_4e6213e9bc                    80  M_ID_979ed661fc         -6
# 3  C_ID_4e6213e9bc                   560  M_ID_e6d5ae8ea6         -5
# 4  C_ID_4e6213e9bc                    80  M_ID_e020e9b302        -11
#
#    purchase_amount        purchase_date
# 0        -0.703331  2017-06-25 15:33:07
# 1        -0.733128  2017-07-15 12:10:45
# 2        -0.720386  2017-08-09 22:04:29
# 3        -0.735352  2017-09-02 10:06:26
# 4        -0.722865  2017-03-10 01:14:19

# %%
new_merchant_transactions = pd.read_csv("../input/new_merchant_transactions.csv")
print("shape of merchants : ",new_merchant_transactions.shape)
new_merchant_transactions.head()
# Out:
# shape of merchants :  (1963031, 14)
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_415bb3a509      107          N             1
# 1               Y  C_ID_415bb3a509      140          N             1
# 2               Y  C_ID_415bb3a509      330          N             1
# 3               Y  C_ID_415bb3a509       -1          Y             1
# 4               Y  C_ID_ef55cf8d4b       -1          Y             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                   307  M_ID_b0c793002c          1
# 1          B                   307  M_ID_88920c89e8          1
# 2          B                   507  M_ID_ad5237ef6b          2
# 3          B                   661  M_ID_9e84cda3b1          1
# 4          B                   166  M_ID_3c86fa3831          1
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# 0        -0.557574  2018-03-11 14:57:36         1.0         9            19
# 1        -0.569580  2018-03-19 18:53:37         1.0         9            19
# 2        -0.551037  2018-04-26 14:08:44         1.0         9            14
# 3        -0.671925  2018-03-07 09:43:21         NaN        -1             8
# 4        -0.659904  2018-03-22 21:07:53         NaN        -1            29

# %%
cardCountTrain = train['card_id'].unique().size
print(cardCountTrain)
print(train['card_id'].size)
cardCountTest = test['card_id'].unique().size
print(cardCountTest)
print(test['card_id'].size)
# Out:
# 201917
# 201917
# 123623
# 123623

# %% [markdown]
# Every value of card_id attribute in Train and Test is unique.

# %%
cardCountTransactions = historical_transactions['card_id'].unique().size
print(cardCountTransactions)
# Out:
# 325540

# %% [markdown]
# We see that: cardCountTrain + cardCountTest = cardCountTransactions,
#
# Lets try to join the dataframes to get all the values.

# %% [markdown]
# Lets also see the correlation of the features 1,2,3 with the target.

# %%
import seaborn as sns

# %%
sns.jointplot(x=train['feature_1'], y=train['target'], data=train)  
plt.show()

sns.jointplot(x=train['feature_2'], y=train['target'], data=train)  
plt.show()

sns.jointplot(x=train['feature_3'], y=train['target'], data=train)  
plt.show()
# Out:
# C:\Users\igor8\Anaconda3\envs\deep learning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
print('unique merchant_id : {0}'.format(historical_transactions['merchant_id'].nunique()))
print('unique merchant_category_id : {0}'.format(historical_transactions['merchant_category_id'].nunique()))
print('unique month_lag : {0}'.format(historical_transactions['month_lag'].nunique()))
print('unique purchase_date : {0}'.format(historical_transactions['purchase_date'].nunique()))
print('unique purchase_amount : {0}'.format(historical_transactions['purchase_amount'].nunique()))
# Out:
# unique merchant_id : 326311
# unique merchant_category_id : 327
# unique month_lag : 14
# unique purchase_date : 16395300
# unique purchase_amount : 215014

# %% [markdown]
# We see that features 1,2,3 distribute uniformly. There is a small amount of possible values for each feature. We would like to get more insights by joining the historical_transactions and train.

# %%
joinedTrain = pd.merge(train, historical_transactions, on = 'card_id',how='left')

# %%
joinedTrain.head(200)
# Out:
#     first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0              2017-06  C_ID_92a2005557          5          2          1
# 1              2017-06  C_ID_92a2005557          5          2          1
# 2              2017-06  C_ID_92a2005557          5          2          1
# 3              2017-06  C_ID_92a2005557          5          2          1
# 4              2017-06  C_ID_92a2005557          5          2          1
# 5              2017-06  C_ID_92a2005557          5          2          1
# 6              2017-06  C_ID_92a2005557          5          2          1
# 7              2017-06  C_ID_92a2005557          5          2          1
# 8              2017-06  C_ID_92a2005557          5          2          1
# 9              2017-06  C_ID_92a2005557          5          2          1
# 10             2017-06  C_ID_92a2005557          5          2          1
# 11             2017-06  C_ID_92a2005557          5          2          1
# 12             2017-06  C_ID_92a2005557          5          2          1
# 13             2017-06  C_ID_92a2005557          5          2          1
# 14             2017-06  C_ID_92a2005557          5          2          1
# 15             2017-06  C_ID_92a2005557          5          2          1
# 16             2017-06  C_ID_92a2005557          5          2          1
# 17             2017-06  C_ID_92a2005557          5          2          1
# 18             2017-06  C_ID_92a2005557          5          2          1
# 19             2017-06  C_ID_92a2005557          5          2          1
# 20             2017-06  C_ID_92a2005557          5          2          1
# 21             2017-06  C_ID_92a2005557          5          2          1
# 22             2017-06  C_ID_92a2005557          5          2          1
# 23             2017-06  C_ID_92a2005557          5          2          1
# 24             2017-06  C_ID_92a2005557          5          2          1
# 25             2017-06  C_ID_92a2005557          5          2          1
# 26             2017-06  C_ID_92a2005557          5          2          1
# 27             2017-06  C_ID_92a2005557          5          2          1
# 28             2017-06  C_ID_92a2005557          5          2          1
# 29             2017-06  C_ID_92a2005557          5          2          1
# ..                 ...              ...        ...        ...        ...
# 170            2017-06  C_ID_92a2005557          5          2          1
# 171            2017-06  C_ID_92a2005557          5          2          1
# 172            2017-06  C_ID_92a2005557          5          2          1
# 173            2017-06  C_ID_92a2005557          5          2          1
# 174            2017-06  C_ID_92a2005557          5          2          1
# 175            2017-06  C_ID_92a2005557          5          2          1
# 176            2017-06  C_ID_92a2005557          5          2          1
# 177            2017-06  C_ID_92a2005557          5          2          1
# 178            2017-06  C_ID_92a2005557          5          2          1
# 179            2017-06  C_ID_92a2005557          5          2          1
# 180            2017-06  C_ID_92a2005557          5          2          1
# 181            2017-06  C_ID_92a2005557          5          2          1
# 182            2017-06  C_ID_92a2005557          5          2          1
# 183            2017-06  C_ID_92a2005557          5          2          1
# 184            2017-06  C_ID_92a2005557          5          2          1
# 185            2017-06  C_ID_92a2005557          5          2          1
# 186            2017-06  C_ID_92a2005557          5          2          1
# 187            2017-06  C_ID_92a2005557          5          2          1
# 188            2017-06  C_ID_92a2005557          5          2          1
# 189            2017-06  C_ID_92a2005557          5          2          1
# 190            2017-06  C_ID_92a2005557          5          2          1
# 191            2017-06  C_ID_92a2005557          5          2          1
# 192            2017-06  C_ID_92a2005557          5          2          1
# 193            2017-06  C_ID_92a2005557          5          2          1
# 194            2017-06  C_ID_92a2005557          5          2          1
# 195            2017-06  C_ID_92a2005557          5          2          1
# 196            2017-06  C_ID_92a2005557          5          2          1
# 197            2017-06  C_ID_92a2005557          5          2          1
# 198            2017-06  C_ID_92a2005557          5          2          1
# 199            2017-06  C_ID_92a2005557          5          2          1
#
#        target  merchant_category_id      merchant_id  month_lag  \
# 0   -0.820283                   195  M_ID_cc72dac895         -3
# 1   -0.820283                   278  M_ID_c9c0f1cb3f         -7
# 2   -0.820283                   683  M_ID_36f9e41993         -6
# 3   -0.820283                   309  M_ID_b790230ee9         -2
# 4   -0.820283                   278  M_ID_ab67f6c982         -7
# 5   -0.820283                   560  M_ID_b3c49066d8         -6
# 6   -0.820283                   560  M_ID_b3c49066d8         -1
# 7   -0.820283                   560  M_ID_b3c49066d8         -7
# 8   -0.820283                    80  M_ID_c124c4467a         -5
# 9   -0.820283                   560  M_ID_1a81c358a3         -7
# 10  -0.820283                   560  M_ID_b3c49066d8          0
# 11  -0.820283                   130  M_ID_166984dc8f         -2
# 12  -0.820283                   454  M_ID_8e24779ad0         -5
# 13  -0.820283                   560  M_ID_1a81c358a3         -7
# 14  -0.820283                   637  M_ID_800c9d11e3         -7
# 15  -0.820283                   526  M_ID_03bb6f5a3b         -2
# 16  -0.820283                   108  M_ID_0888bdef7e         -5
# 17  -0.820283                    80  M_ID_c124c4467a         -6
# 18  -0.820283                   884  M_ID_9122ebdd02         -5
# 19  -0.820283                   454  M_ID_4b30e99bda         -4
# 20  -0.820283                   560  M_ID_1a81c358a3         -7
# 21  -0.820283                   454  M_ID_6b718b517f         -4
# 22  -0.820283                   561  M_ID_50f575c681         -5
# 23  -0.820283                   478  M_ID_de54dcf09d         -4
# 24  -0.820283                   454  M_ID_eb154b339f         -2
# 25  -0.820283                   278  M_ID_0ef7af562d         -2
# 26  -0.820283                   454  M_ID_6b718b517f         -1
# 27  -0.820283                   879  M_ID_00a6ca8a8a          0
# 28  -0.820283                   454  M_ID_800c9d11e3         -2
# 29  -0.820283                   195  M_ID_cc72dac895         -1
# ..        ...                   ...              ...        ...
# 170 -0.820283                   560  M_ID_1a81c358a3         -6
# 171 -0.820283                   387  M_ID_a79f97e414         -2
# 172 -0.820283                   560  M_ID_940fb4498f         -5
# 173 -0.820283                    33  M_ID_a0c228f362         -4
# 174 -0.820283                   278  M_ID_f1ab535812         -3
# 175 -0.820283                   560  M_ID_b3c49066d8         -4
# 176 -0.820283                   683  M_ID_cc72dac895         -2
# 177 -0.820283                   195  M_ID_f8ff2ae0cb         -2
# 178 -0.820283                   561  M_ID_50f575c681         -2
# 179 -0.820283                   560  M_ID_1a81c358a3         -7
# 180 -0.820283                   683  M_ID_36f9e41993         -6
# 181 -0.820283                   879  M_ID_00a6ca8a8a         -3
# 182 -0.820283                   454  M_ID_6b718b517f         -3
# 183 -0.820283                   454  M_ID_800c9d11e3         -3
# 184 -0.820283                   195  M_ID_cc72dac895          0
# 185 -0.820283                   108  M_ID_0888bdef7e          0
# 186 -0.820283                   779  M_ID_855512f895         -2
# 187 -0.820283                   683  M_ID_5518af06f8         -6
# 188 -0.820283                    80  M_ID_5ba019a379         -6
# 189 -0.820283                   560  M_ID_0b57129617         -6
# 190 -0.820283                   454  M_ID_44ab1b4f02         -7
# 191 -0.820283                    80  M_ID_5ba019a379         -6
# 192 -0.820283                   179  M_ID_0e9fbd2686          0
# 193 -0.820283                   683  M_ID_5518af06f8         -2
# 194 -0.820283                   195  M_ID_27ef0c464c         -6
# 195 -0.820283                   813  M_ID_338b03705f         -6
# 196 -0.820283                   705              NaN         -1
# 197 -0.820283                   560  M_ID_1a81c358a3         -5
# 198 -0.820283                   560  M_ID_1a81c358a3         -7
# 199 -0.820283                   179  M_ID_0e9fbd2686          0
#
#      purchase_amount        purchase_date
# 0          -0.506033  2017-11-25 16:37:11
# 1          -0.722114  2017-07-16 12:21:00
# 2          -0.726171  2017-08-10 21:01:16
# 3          -0.610167  2017-12-15 12:06:58
# 4          -0.307232  2017-07-08 15:13:18
# 5          -0.662158  2017-08-13 13:43:07
# 6          -0.665614  2018-01-27 06:44:29
# 7          -0.727944  2017-07-01 09:02:20
# 8          -0.620986  2017-09-02 23:05:56
# 9          -0.722114  2017-07-27 08:17:48
# 10         -0.595230  2018-02-25 09:25:39
# 11         -0.491457  2017-12-20 11:55:05
# 12         -0.686802  2017-09-30 20:06:30
# 13         -0.700356  2017-07-07 13:58:08
# 14         -0.731881  2017-07-12 15:20:45
# 15         -0.656749  2017-12-20 18:28:09
# 16         -0.494883  2017-09-07 16:30:10
# 17         -0.599949  2017-08-26 21:51:48
# 18         -0.638717  2017-09-17 19:48:49
# 19         -0.728876  2017-10-09 18:42:12
# 20         -0.726171  2017-07-26 08:08:11
# 21         -0.709342  2017-10-04 18:52:58
# 22         -0.677681  2017-09-16 01:30:25
# 23         -0.580114  2017-10-05 18:48:46
# 24         -0.728876  2017-12-14 09:56:57
# 25         -0.362109  2017-12-11 13:40:13
# 26         -0.712347  2018-01-09 10:06:54
# 27         -0.707899  2018-02-17 09:39:17
# 28         -0.722865  2017-12-13 16:01:01
# 29         -0.589580  2018-01-13 14:23:54
# ..               ...                  ...
# 170        -0.718087  2017-08-09 15:07:22
# 171        -0.643225  2017-12-19 11:36:59
# 172        -0.672076  2017-09-09 13:06:22
# 173        -0.701828  2017-10-23 18:02:20
# 174        -0.716750  2017-11-11 00:00:00
# 175        -0.728335  2017-10-22 12:30:15
# 176        -0.728876  2017-12-27 14:33:33
# 177        -0.446678  2017-12-17 17:35:00
# 178        -0.578611  2017-12-15 21:57:05
# 179        -0.707223  2017-07-11 12:29:27
# 180        -0.708891  2017-08-10 21:10:51
# 181        -0.641722  2017-11-11 11:30:24
# 182        -0.709041  2017-11-19 19:56:30
# 183        -0.716855  2017-11-29 13:00:28
# 184        -0.703030  2018-02-16 12:02:24
# 185        -0.715352  2018-02-18 13:24:31
# 186        -0.716855  2017-12-28 14:10:21
# 187        -0.724518  2017-08-26 19:57:36
# 188        -0.676283  2017-08-29 14:11:32
# 189        -0.737141  2017-08-19 16:25:16
# 190        -0.689807  2017-07-05 16:33:41
# 191        -0.739395  2017-08-13 16:29:41
# 192        -0.648860  2018-02-05 15:26:16
# 193        -0.708590  2017-12-11 11:39:39
# 194        -0.696073  2017-08-10 20:58:15
# 195        -0.734180  2017-08-27 13:26:06
# 196        -0.701979  2018-01-28 11:10:23
# 197        -0.706381  2017-09-15 17:02:54
# 198        -0.706742  2017-07-05 13:22:16
# 199        -0.670273  2018-02-07 14:18:25
#
# [200 rows x 11 columns]

# %%
joinedTrain.dropna(inplace=True)
joinedTrain.shape
# Out:
# (17943982, 11)

# %%
joinedTrain['target'].hist(alpha=0.5)

# %% [markdown]
# ## Starting to preproccess the data:

# %% [markdown]
# We want to normalize the numeric features (features 1,2,3) to be in the acceptable range for the model, also we enumerate the other features to have a one hot encoding.

# %%
from sklearn import preprocessing

target = train['target'].values
min_max_scaler = preprocessing.MinMaxScaler()
normalizedTarget = min_max_scaler.fit_transform(target.reshape(-1, 1))

# %%
normalizedTarget
# Out:
# array([[0.63298643],
#        [0.6566889 ],
#        [0.66245517],
#        ...,
#        [0.65083909],
#        [0.5576449 ],
#        [0.6126847 ]])

# %%
target
# Out:
# array([-0.8202826 ,  0.39291325,  0.68805599, ...,  0.09349415,
#        -4.67658938, -1.85941301])

# %%
min_max_scaler.inverse_transform(normalizedTarget.reshape(1,-1))
# Out:
# array([[-0.8202826 ,  0.39291325,  0.68805599, ...,  0.09349415,
#         -4.67658938, -1.85941301]])

# %% [markdown]
# ## Starting to create the embeddings:
#
# We create an embedding with depth of 5 for each feature in the present data.

# %%
first_active_month = {p:i for (i,p) in enumerate(train['first_active_month'])}
card_id = {p:i for (i,p) in enumerate(train['card_id'])}
feature_1 = min_max_scaler.fit_transform(train['feature_1'].values.reshape(-1, 1))
feature_2 = min_max_scaler.fit_transform(train['feature_2'].values.reshape(-1, 1))
feature_3 = min_max_scaler.fit_transform(train['feature_3'].values.reshape(-1, 1))
# Out:
# C:\Users\igor8\Anaconda3\envs\deep learning\lib\site-packages\sklearn\utils\validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\igor8\Anaconda3\envs\deep learning\lib\site-packages\sklearn\utils\validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\igor8\Anaconda3\envs\deep learning\lib\site-packages\sklearn\utils\validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
processed_data = train.loc[:,['first_active_month','card_id','feature_1','feature_2',
                                    'feature_3']].copy()
processed_data['first_active_month'] = [first_active_month[x] for x in train['first_active_month']]
processed_data['card_id'] = [card_id[x] for x in train['card_id']]
processed_data['feature_1'] = feature_1
processed_data['feature_2'] = feature_2
processed_data['feature_3'] = feature_3

# %%
first_active_inp = Input(shape=(1,),dtype='int64')
card_inp = Input(shape=(1,),dtype='int64')
f1_inp = Input(shape=(1,),dtype='int64')
f2_inp = Input(shape=(1,),dtype='int64')
f3_inp = Input(shape=(1,),dtype='int64')

first_active_emb = Embedding(len(card_id),5,input_length=1)(first_active_inp)
card_emb = Embedding(len(card_id),5,input_length=1)(card_inp)
f1_emb = Embedding(len(card_id),5,input_length=1)(f1_inp)
f2_emb = Embedding(len(card_id),5,input_length=1)(f2_inp)
f3_emb = Embedding(len(card_id),5,input_length=1)(f3_inp)

# %%
first_active_emb
# Out:
# <tf.Tensor 'embedding_1/embedding_lookup:0' shape=(?, 1, 5) dtype=float32>

# %% [markdown]
# ## Building the model:

# %%
x = concatenate([first_active_emb,card_emb,f1_emb,f2_emb,f3_emb])
x = Flatten()(x)
x = BatchNormalization()(x)
x = Dense(100,activation='relu')(x)
x = Dense(25,activation='relu')(x)
x = Dense(10,activation='relu')(x)
x = Dense(5,activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(1,activation='relu')(x)
nn_model = Model([first_active_inp,card_inp,f1_inp,f2_inp,f3_inp],x)
nn_model.compile(loss = 'mae',optimizer='adam')

# %%
nn_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 5)         1009585     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 5)         1009585     input_2[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 5)         1009585     input_3[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 1, 5)         1009585     input_4[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 1, 5)         1009585     input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1, 25)        0           embedding_1[0][0]
#                                                                  embedding_2[0][0]
#                                                                  embedding_3[0][0]
#                                                                  embedding_4[0][0]
#                                                                  embedding_5[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 25)           0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25)           100         flatten_7[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 100)          2600        batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 25)           2525        dense_22[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 10)           260         dense_23[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 5)            55          dense_24[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 5)            0           dense_25[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 1)            6           dropout_2[0][0]
# ==================================================================================================
# Total params: 5,053,471
# Trainable params: 5,053,421
# Non-trainable params: 50
# __________________________________________________________________________________________________

# %%
from sklearn.model_selection import KFold,StratifiedKFold
from sklearn.model_selection import train_test_split

def set_callbacks(description='run1',patience=15,tb_base_logdir='./logs/'):
    cp = ModelCheckpoint('best_model_weights_{}.h5'.format(description),save_best_only=True)
    rlop = ReduceLROnPlateau(patience=5)   
    cb = [cp,rlop]
    return cb

features = processed_data.columns
X_train,X_val,y_train,y_val = train_test_split(processed_data, normalizedTarget, test_size=0.2)

# %%
print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (161533, 5)
# (40384, 5)
# (161533, 1)
# (40384, 1)

# %%
min_max_scaler.inverse_transform(y_val.reshape(1,-1))
# Out:
# array([[0.63957996, 0.66757111, 0.63607923, ..., 0.64910574, 0.72315046,
#         0.58415798]])

# %% [markdown]
# ## Fitting the model:

# %%
history = nn_model.fit([X_train[f] for f in features],y_train,epochs=7, batch_size=1000,
             validation_data=[[X_val[f] for f in features],y_val],callbacks=set_callbacks())
# Out:
# Train on 161533 samples, validate on 40384 samples
# Epoch 1/7
# 161533/161533 [==============================] - 22s 135us/step - loss: 0.2016 - val_loss: 0.1008
# Epoch 2/7
# 161533/161533 [==============================] - 21s 131us/step - loss: 0.1148 - val_loss: 0.1018
# Epoch 3/7
# 161533/161533 [==============================] - 19s 117us/step - loss: 0.0942 - val_loss: 0.0845
# Epoch 4/7
# 161533/161533 [==============================] - 20s 123us/step - loss: 0.0693 - val_loss: 0.0602
# Epoch 5/7
# 161533/161533 [==============================] - 20s 121us/step - loss: 0.0453 - val_loss: 0.0388
# Epoch 6/7
# 161533/161533 [==============================] - 19s 120us/step - loss: 0.0242 - val_loss: 0.0200
# Epoch 7/7
# 161533/161533 [==============================] - 19s 119us/step - loss: 0.0141 - val_loss: 0.0143

# %% [markdown]
# ## Looking at the results we got:

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
nn_model.load_weights('./best_model_weights_run1.h5')
preds = nn_model.predict([X_val[f] for f in features])

# %%
preds
min_max_scaler.inverse_transform(preds.reshape(1,-1))
# Out:
# array([[0.6418802 , 0.6465378 , 0.64141613, ..., 0.64373   , 0.7109308 ,
#         0.62586117]], dtype=float32)

# %%
predsDF = pd.DataFrame(data = preds)
testDF = pd.DataFrame(data = y_val)

# %%
fig, ax = plt.subplots()
ax.scatter(y_val, preds)
ax.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
from sklearn.metrics import r2_score 

print('The score of model in validation is:')
print(r2_score(testDF.values,predsDF.values))
# Out:
# The score of model in validation is:
# 0.7926107021029271

# %% [markdown]
# ## Preprocessing the test samples and predictions

# %%
first_active_month = {p:i for (i,p) in enumerate(test['first_active_month'])}
card_id = {p:i for (i,p) in enumerate(test['card_id'])}
feature_1 = min_max_scaler.fit_transform(test['feature_1'].values.reshape(-1, 1))
feature_2 = min_max_scaler.fit_transform(test['feature_2'].values.reshape(-1, 1))
feature_3 = min_max_scaler.fit_transform(test['feature_3'].values.reshape(-1, 1))

test_processed_data = test.loc[:,['first_active_month','card_id','feature_1','feature_2',
                                    'feature_3']].copy()
test_processed_data['first_active_month'] = [first_active_month[x] for x in test['first_active_month']]
test_processed_data['card_id'] = [card_id[x] for x in test['card_id']]
test_processed_data['feature_1'] = feature_1
test_processed_data['feature_2'] = feature_2
test_processed_data['feature_3'] = feature_3
# Out:
# C:\Users\igor8\Anaconda3\envs\deep learning\lib\site-packages\sklearn\utils\validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\igor8\Anaconda3\envs\deep learning\lib\site-packages\sklearn\utils\validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\igor8\Anaconda3\envs\deep learning\lib\site-packages\sklearn\utils\validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
nn_model.load_weights('./best_model_weights_run1.h5')
testpreds = nn_model.predict([test_processed_data[f] for f in features])

# %%
flat_list = [item for sublist in testpreds for item in sublist]
testDF2 = pd.DataFrame(data = flat_list)
flat_list = np.asarray(flat_list)

# %%
answers = min_max_scaler.inverse_transform(flat_list.reshape(1,-1))[0]
answers
# Out:
# array([0.63524556, 0.6596994 , 0.63123053, ..., 0.6528221 , 0.6378513 ,
#        0.6125588 ], dtype=float32)

# %%
sub = pd.read_csv("../input/sample_submission.csv")
sub.reset_index(drop = True)
sub['target'] = answers
sub.to_csv('sub.csv')

# %% [markdown]
# ## ML Benchmark:

# %%
from sklearn.linear_model import LinearRegression


mlTarget = train['target']
lm = LinearRegression()
lm.fit(processed_data,normalizedTarget)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.score(processed_data,normalizedTarget)
# Out:
# 0.0003748758233746985
